# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2
# Out:
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2

# %%
#!python utils/create_random_splits.py --data_dirs Datasets/plane

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (0.21.0+cu124)
# Requirement already satisfied: ultralytics==8.3.96 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (8.3.96)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (4.11.0.86)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (11.1.0)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (1.14.1)
# Requirement already satisfied: pycocotools>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (2.0.8)
# Requirement already satisfied: loguru in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.7.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (13.9.4)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (9.0.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (8.4.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (2.1.0)
# Requirement already satisfied: albumentations>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (2.0.5)
# Requirement already satisfied: ipywidgets>=8.1.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (8.1.6)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (1.11.1.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (0.9.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (0.1.1.post2209072238)
# Requirement already satisfied: tensorboard>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (2.18.0)
# Requirement already satisfied: matplotlib>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 31)) (3.10.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 32)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 33)) (0.13.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 46)) (7.34.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.96->-r requirements.txt (line 4)) (2.0.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->-r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.6.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->-r requirements.txt (line 17)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->-r requirements.txt (line 17)) (2.18.0)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations>=1.0.3->-r requirements.txt (line 23)) (2.11.3)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations>=1.0.3->-r requirements.txt (line 23)) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations>=1.0.3->-r requirements.txt (line 23)) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations>=1.0.3->-r requirements.txt (line 23)) (3.12.4)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations>=1.0.3->-r requirements.txt (line 23)) (6.2.1)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.5->-r requirements.txt (line 24)) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.5->-r requirements.txt (line 24)) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.5->-r requirements.txt (line 24)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.5->-r requirements.txt (line 24)) (3.0.14)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (3.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r requirements.txt (line 28)) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.10.1->-r requirements.txt (line 31)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.10.1->-r requirements.txt (line 31)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.10.1->-r requirements.txt (line 31)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.10.1->-r requirements.txt (line 31)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.10.1->-r requirements.txt (line 31)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.10.1->-r requirements.txt (line 31)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 32)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 32)) (2025.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 46)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 46)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 46)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 46)) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 46)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 46)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->-r requirements.txt (line 46)) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->-r requirements.txt (line 46)) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 17)) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->-r requirements.txt (line 46)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r requirements.txt (line 46)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations>=1.0.3->-r requirements.txt (line 23)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations>=1.0.3->-r requirements.txt (line 23)) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations>=1.0.3->-r requirements.txt (line 23)) (0.4.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.13.0->-r requirements.txt (line 28)) (3.0.2)

# %%
# !pip uninstall -y wandb
# Out:
# WARNING: Skipping wandb as it is not installed.

# %%
from competition_utils import *

# 제출 함수를 리스트로 정의 (submission_N_학번)
# 깃허브에는 최대 3개 업로드 데모시 하이퍼파라미터 튜닝 후 1개만 제출

submission_functions = ['submission_1_20223292', 'submission_2_20223292','submission_3_20223292']
for submission_function in submission_functions:
    exec(f"from {submission_function} import {submission_function}")



# 분석 방향에 따라 iteration 수정
# 평가시에는 데모와 다른 스플릿 시드를 만들어 [1, 10]로 진행 예정
iterations = [1,8]

# 'Crown Detection'는 예제 데이터셋, 데모 및 평가시에는 'CV_Competition'
Dataset_Name = 'plane'

# 결과를 모아 하나의 csv 파일에 저장
results_df = pd.DataFrame(columns=[
    'Experiment Time', 'Iteration', 'Submission Function',
    'IoU', 'Dice', 'Precision', 'Recall', 'Output Json Path',
])
csv_filename = f"Evaluation_Results_{datetime.now().strftime('%y%m%d_%H%M%S')}.csv"

# 서로 다른 iteration, submission function으로 실험 진행
for iteration in range(iterations[0], iterations[1]+1):
    yaml_path = f'Datasets/{Dataset_Name}/data_iter_{iteration:02d}.yaml'


    for submission_function in submission_functions:
        ex_time = datetime.now().strftime('%y%m%d_%H%M%S')
        output_json_path = f"{ex_time}_{submission_function}_Iter_{iteration}_detection_results.json"
        globals()[submission_function](yaml_path, output_json_path)
        labels_dir = f"Datasets/{Dataset_Name}/labels"



        vis_output_dir = f"{ex_time}_visualization_results"
        image_level_result_path =f"{ex_time}_{submission_function}_Iter_{iteration}_image_level_results.json"
        stats = eval_and_vis(yaml_path, output_json_path, labels_dir, image_level_result_path, vis_output_dir, vis=False) # 분석 방향에 따라 vis=True 설정

        new_row = {
            'Experiment Time': ex_time,
            'Iteration': iteration,
            'Submission Function': submission_function,
            'IoU': stats['IoU']['avg'],
            'Dice': stats['Dice']['avg'],
            'Precision': stats['Precision']['avg'],
            'Recall': stats['Recall']['avg'],
            'Output Json Path': output_json_path,
        }


        results_df = pd.concat([results_df, pd.DataFrame([new_row])], ignore_index=True)
        results_df.to_csv(csv_filename, index=False)
# Out:
# ✅ 데이터셋이 이미 증강되어 있습니다. 작업을 건너뜁니다.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[3, 16, 3, 2]
#   1                  -1  1      4672  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[16, 32, 3, 2]
#   2                  -1  1      7360  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[32, 32, 1, True]
#   3                  -1  1     18560  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[32, 64, 3, 2]
#   4                  -1  2     62912  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.MANet[64, 64, 2, True, 1, 3]
#   5                  -1  1     73984  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[64, 128, 3, 2]
#   6                  -1  2    248704  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.MANet[128, 128, 2, True, 1, 3]
#   7                  -1  1    295424  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[128, 256, 3, 2]
#   8                  -1  1    460288  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[256, 256, 1, True]
#   9                  -1  1    164608  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.SPPF[256, 256, 5]
#  10                   0  1         0  torch.nn.modules.pooling.AvgPool2d           [8, 8, 0]
#  11                   2  1         0  torch.nn.modules.pooling.AvgPool2d           [4, 4, 0]
#  12                   4  1         0  torch.nn.modules.pooling.AvgPool2d           [2, 2, 0]
#  13                   9  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14 [10, 11, 12, 6, 13]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  15                  -1  1     63744  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[496, 128, 1, 1]
#  16                  -1  1     16768  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.HyperComputeModule[128, 128, 6]
#  17                  -1  1    166528  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.MANet[128, 128, 1, True]
#  18                  -1  1         0  torch.nn.modules.pooling.AvgPool2d           [2, 2, 0]
#  19             [-1, 9]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  20                  -1  1     98816  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[384, 256, 1, 1]
#  21             [17, 6]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  22                  -1  1    131840  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[256, 128, 1, False]
#  23                  17  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  24             [-1, 4]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  25                  -1  1     37248  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[192, 64, 1, False]
#  26                  -1  1     36992  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[64, 64, 3, 2]
#  27            [-1, 22]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  28                  -1  1    123648  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[192, 128, 1, False]
#  29                  -1  1    147712  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[128, 128, 3, 2]
#  30            [-1, 20]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  31                  -1  1     98816  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[384, 256, 1, 1]
#  32        [25, 28, 31]  1    897664  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.head.Detect[80, [64, 128, 256]]
# Hyper-YOLOt summary: 286 layers, 3156752 parameters, 3156736 gradients, 9.7 GFLOPs
#
# Hyper-YOLOv1.0 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: task=detect, mode=train, model=HyperYOLOt.yaml, data=Datasets/plane/data_iter_01.yaml, epochs=20, patience=100, batch=16, imgsz=640, save=True, val_period=1, start_val_epoch=0, save_period=-1, cache=False, device=cuda:0, workers=8, project=output/250422_200313/train, name=250422_200313_HyperYOLOt_plane_Iter_1, exist_ok=False, pretrained=False, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=True, rect=False, cos_lr=True, close_mosaic=2, resume=False, amp=False, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=True, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=False, show_conf=False, show_boxes=False, line_width=1, format=onnx, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=2.0, warmup_momentum=0.85, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[3, 16, 3, 2]
#   1                  -1  1      4672  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[16, 32, 3, 2]
#   2                  -1  1      7360  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[32, 32, 1, True]
#   3                  -1  1     18560  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[32, 64, 3, 2]
#   4                  -1  2     62912  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.MANet[64, 64, 2, True, 1, 3]
#   5                  -1  1     73984  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[64, 128, 3, 2]
#   6                  -1  2    248704  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.MANet[128, 128, 2, True, 1, 3]
#   7                  -1  1    295424  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[128, 256, 3, 2]
#   8                  -1  1    460288  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[256, 256, 1, True]
#   9                  -1  1    164608  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.SPPF[256, 256, 5]
#  10                   0  1         0  torch.nn.modules.pooling.AvgPool2d           [8, 8, 0]
#  11                   2  1         0  torch.nn.modules.pooling.AvgPool2d           [4, 4, 0]
#  12                   4  1         0  torch.nn.modules.pooling.AvgPool2d           [2, 2, 0]
#  13                   9  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14 [10, 11, 12, 6, 13]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  15                  -1  1     63744  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[496, 128, 1, 1]
#  16                  -1  1     16768  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.HyperComputeModule[128, 128, 6]
#  17                  -1  1    166528  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.MANet[128, 128, 1, True]
#  18                  -1  1         0  torch.nn.modules.pooling.AvgPool2d           [2, 2, 0]
#  19             [-1, 9]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  20                  -1  1     98816  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[384, 256, 1, 1]
#  21             [17, 6]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  22                  -1  1    131840  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[256, 128, 1, False]
#  23                  17  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  24             [-1, 4]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  25                  -1  1     37248  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[192, 64, 1, False]
#  26                  -1  1     36992  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[64, 64, 3, 2]
#  27            [-1, 22]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  28                  -1  1    123648  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.block.C2f[192, 128, 1, False]
#  29                  -1  1    147712  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[128, 128, 3, 2]
#  30            [-1, 20]  1         0  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Concat[1]
#  31                  -1  1     98816  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.conv.Conv[384, 256, 1, 1]
#  32        [25, 28, 31]  1    751507  models.HyperYOLOt.pkgs.hyper_ultralytics.nn.modules.head.Detect[1, [64, 128, 256]]
# Hyper-YOLOt summary: 286 layers, 3010595 parameters, 3010579 gradients, 9.0 GFLOPs
#
# TensorBoard: Start with 'tensorboard --logdir output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1', view at http://localhost:6006/
# Freezing layer 'model.32.dfl.conv.weight'
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/HyperYOLOt/pkgs/hyper_ultralytics/engine/trainer.py:239: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.amp)
# train: Scanning Datasets/plane/labels... 1308 images, 6 backgrounds, 0 corrupt: 100%|██████████| 1308/1308 [00:21<00:00, 61.06it/s]
# train: New cache created: Datasets/plane/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/HyperYOLOt/pkgs/hyper_ultralytics/data/augment.py:840: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0)]  # transforms
# /usr/local/lib/python3.11/dist-packages/albumentations/core/composition.py:250: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# val: Scanning Datasets/plane/labels... 218 images, 1 backgrounds, 0 corrupt: 100%|██████████| 218/218 [00:01<00:00, 178.51it/s]
# val: New cache created: Datasets/plane/labels.cache
# Plotting labels to output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1/labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 73 weight(decay=0.0), 80 weight(decay=0.0005), 80 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      5.06G      3.204      3.106      3.475         28        640: 100%|██████████| 82/82 [00:10<00:00,  7.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  4.13it/s]
#                    all        218        278   0.000875      0.194   0.000529   0.000139
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      5.07G      2.811      2.898      3.115         25        640: 100%|██████████| 82/82 [00:09<00:00,  8.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  4.50it/s]
#                    all        218        278    0.00138      0.108    0.00045   0.000168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      5.07G      2.558      2.665      2.897         34        640: 100%|██████████| 82/82 [00:08<00:00,  9.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.99it/s]
#                    all        218        278    0.00564      0.302    0.00399    0.00132
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      5.08G      2.427      2.483      2.731         25        640: 100%|██████████| 82/82 [00:08<00:00,  9.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  6.37it/s]
#                    all        218        278      0.161      0.173     0.0563     0.0232
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      5.09G      2.275      2.364      2.622         38        640: 100%|██████████| 82/82 [00:09<00:00,  8.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.25it/s]
#                    all        218        278       0.14      0.115      0.091     0.0279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      5.11G      2.174      2.254       2.56         20        640: 100%|██████████| 82/82 [00:09<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.89it/s]
#                    all        218        278      0.475      0.345      0.302      0.123
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      5.12G      2.078      2.158      2.445         26        640: 100%|██████████| 82/82 [00:09<00:00,  8.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.16it/s]
#                    all        218        278       0.69      0.245      0.319      0.166
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      5.13G      1.994      2.065      2.366         29        640: 100%|██████████| 82/82 [00:09<00:00,  8.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.70it/s]
#                    all        218        278      0.317      0.424      0.272     0.0909
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      5.14G      1.923      1.996      2.319         23        640: 100%|██████████| 82/82 [00:09<00:00,  9.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.41it/s]
#                    all        218        278      0.564      0.371      0.437      0.258
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      5.16G      1.881      1.954      2.266         21        640: 100%|██████████| 82/82 [00:10<00:00,  8.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.73it/s]
#                    all        218        278      0.427      0.496      0.472      0.259
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      5.07G      1.779      1.895      2.233         37        640: 100%|██████████| 82/82 [00:09<00:00,  8.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.79it/s]
#                    all        218        278      0.679      0.363      0.465      0.245
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      5.08G      1.778      1.855      2.178         38        640: 100%|██████████| 82/82 [00:09<00:00,  8.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.44it/s]
#                    all        218        278      0.698      0.582       0.65      0.383
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      5.09G      1.685      1.748      2.114         26        640: 100%|██████████| 82/82 [00:09<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.10it/s]
#                    all        218        278      0.726      0.594      0.658       0.41
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      5.11G      1.623      1.696      2.081         28        640: 100%|██████████| 82/82 [00:09<00:00,  8.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.27it/s]
#                    all        218        278       0.72      0.665      0.679      0.411
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      5.12G      1.591      1.652      2.006         34        640: 100%|██████████| 82/82 [00:09<00:00,  8.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.59it/s]
#                    all        218        278      0.755      0.637      0.672      0.425
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      5.13G      1.563      1.617       1.98         41        640: 100%|██████████| 82/82 [00:09<00:00,  8.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.16it/s]
#                    all        218        278      0.709      0.647      0.675      0.428
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      5.14G       1.52      1.545      1.948         27        640: 100%|██████████| 82/82 [00:09<00:00,  8.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.65it/s]
#                    all        218        278      0.812      0.716      0.746        0.5
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      5.13G      1.474       1.52      1.913         35        640: 100%|██████████| 82/82 [00:09<00:00,  9.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  4.68it/s]
#                    all        218        278      0.831      0.719      0.768      0.527
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/HyperYOLOt/pkgs/hyper_ultralytics/data/augment.py:840: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0)]  # transforms
# /usr/local/lib/python3.11/dist-packages/albumentations/core/composition.py:250: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      5.11G      1.289      1.343      1.838         12        640: 100%|██████████| 82/82 [00:10<00:00,  7.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.78it/s]
#                    all        218        278      0.859      0.721      0.771      0.542
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      5.11G      1.223      1.198      1.818         16        640: 100%|██████████| 82/82 [00:09<00:00,  8.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  5.79it/s]
#                    all        218        278       0.88      0.766      0.804      0.571
# 20 epochs completed in 0.067 hours.
# Optimizer stripped from output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1/weights/last.pt, 6.3MB
# Optimizer stripped from output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1/weights/best.pt, 6.3MB
#
# Validating output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1/weights/best.pt...
# Hyper-YOLOv1.0 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Hyper-YOLOt summary (fused): 214 layers, 3004179 parameters, 0 gradients, 8.9 GFLOPs
# Hyper-YOLOt summary (fused): 214 layers, 3004179 parameters, 0 gradients, 8.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:02<00:00,  3.35it/s]
#                    all        218        278       0.88      0.765      0.804      0.571
#                    all        218        278       0.88      0.765      0.804      0.571
# Speed: 0.1ms preprocess, 1.5ms inference, 0.0ms loss, 2.1ms postprocess per image
# Speed: 0.1ms preprocess, 1.5ms inference, 0.0ms loss, 2.1ms postprocess per image
# Saving output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1/predictions.json...
# Saving output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1/predictions.json...
#
# Evaluating pycocotools mAP using output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1/predictions.json and /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/Datasets/plane/annotations/instances_val2017.json...
#
# Evaluating pycocotools mAP using output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1/predictions.json and /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/Datasets/plane/annotations/instances_val2017.json...
# pycocotools unable to run: /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/Datasets/plane/annotations/instances_val2017.json file not found
# pycocotools unable to run: /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/Datasets/plane/annotations/instances_val2017.json file not found
# Results saved to output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1
# Results saved to output/250422_200313/train/250422_200313_HyperYOLOt_plane_Iter_1
# Transferred 452/452 items from pretrained weights
# Transferred 452/452 items from pretrained weights
# 결과가 250422_200313_submission_1_20223292_Iter_1_detection_results.json에 저장되었습니다.
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  models.FLDetn.pkgs.ultralytics.nn.modules.conv.Conv[3, 16, 3, 2]
#   1                  -1  1      4672  models.FLDetn.pkgs.ultralytics.nn.modules.conv.Conv[16, 32, 3, 2]
#   2                  -1  1     14208  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.IEPR[32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.IEPR[32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  models.FLDetn.pkgs.ultralytics.nn.modules.conv.Conv[32, 64, 3, 2]
#   5                  -1  1     52992  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.IEPR[64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.ECM[64, 13, 0.25, 3]
#   7                  -1  1     52992  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.IEPR[64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  models.FLDetn.pkgs.ultralytics.nn.modules.conv.Conv[64, 128, 3, 2]
#   9                  -1  1    175104  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.ECM[128, 13, 0.25, 3]
#  10                  -1  1    175104  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.ECM[128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.CSNeck3in[32, 64, 128, False, 2]
#  12                  -1  1    240164  models.FLDetn.pkgs.ultralytics.nn.modules.head.Detect['SiLU', 'normal', 10, (32, 128)]
# ✅ 데이터셋이 이미 증강되어 있습니다. 작업을 건너뜁니다.
# FLDet-N summary: 409 layers, 1179380 parameters, 1179364 gradients, 12.7 GFLOPs
#
# Ultralytics YOLOv8.3.96 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: task=detect, mode=train, model=FLDetn.yaml, data=Datasets/plane/data_iter_01.yaml, epochs=20, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=output/250422_200313/train, name=250422_200802_FLDetn_plane_Iter_1, exist_ok=False, pretrained=False, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=True, rect=False, cos_lr=True, close_mosaic=2, resume=False, amp=False, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=2.0, warmup_momentum=0.85, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, testspeed=False, get_raw_output=False, decay_aug=False, close_copy_paste=0, close_mixup=0, tracker=botsort.yaml, save_dir=output/250422_200313/train/250422_200802_FLDetn_plane_Iter_1
# Overriding model.yaml nc=10 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  models.FLDetn.pkgs.ultralytics.nn.modules.conv.Conv[3, 16, 3, 2]
#   1                  -1  1      4672  models.FLDetn.pkgs.ultralytics.nn.modules.conv.Conv[16, 32, 3, 2]
#   2                  -1  1     14208  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.IEPR[32, 32, 2, 2, True, 'deepextend']
#   3                  -1  1     14208  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.IEPR[32, 32, 2, 2, True, 'deepextend']
#   4                  -1  1     18560  models.FLDetn.pkgs.ultralytics.nn.modules.conv.Conv[32, 64, 3, 2]
#   5                  -1  1     52992  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.IEPR[64, 64, 2, 2, True, 'deepextend']
#   6                  -1  1     46592  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.ECM[64, 13, 0.25, 3]
#   7                  -1  1     52992  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.IEPR[64, 64, 2, 2, True, 'deepextend']
#   8                  -1  1     73984  models.FLDetn.pkgs.ultralytics.nn.modules.conv.Conv[64, 128, 3, 2]
#   9                  -1  1    175104  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.ECM[128, 13, 0.25, 3]
#  10                  -1  1    175104  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.ECM[128, 13, 0.25, 3]
#  11          [3, 7, 10]  1    310336  models.FLDetn.pkgs.ultralytics.nn.modules.csdet_block.CSNeck3in[32, 64, 128, False, 2]
#  12                  -1  1    239570  models.FLDetn.pkgs.ultralytics.nn.modules.head.Detect['SiLU', 'normal', 1, (32, 128)]
# FLDet-N summary: 409 layers, 1178786 parameters, 1178770 gradients, 12.7 GFLOPs
#
# TensorBoard: Start with 'tensorboard --logdir output/250422_200313/train/250422_200802_FLDetn_plane_Iter_1', view at http://localhost:6006/
# Freezing layer 'model.12.dfl.conv.weight'
# train: Scanning Datasets/plane/labels... 1308 images, 6 backgrounds, 0 corrupt: 100%|██████████| 1308/1308 [00:17<00:00, 76.14it/s]
# train: New cache created: Datasets/plane/labels.cache
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/FLDetn/pkgs/ultralytics/data/augment.py:663: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0)]  # transforms
# /usr/local/lib/python3.11/dist-packages/albumentations/core/composition.py:250: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning Datasets/plane/labels... 218 images, 1 backgrounds, 0 corrupt: 100%|██████████| 218/218 [00:01<00:00, 170.38it/s]
# val: New cache created: Datasets/plane/labels.cache
# Plotting labels to output/250422_200313/train/250422_200802_FLDetn_plane_Iter_1/labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 98 weight(decay=0.0), 103 weight(decay=0.0005), 102 bias(decay=0.0)
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/FLDetn/pkgs/ultralytics/nn/modules/csdet_block.py:340: TracerWarning: torch.from_numpy results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   kernel = torch.from_numpy(kernel_value).to(branch.weight.device)
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py:836: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   return builtins.int(a)  # type: ignore[operator]
# WARNING ⚠️ TensorBoard graph visualization failure Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument max in method wrapper_CUDA_clamp_Tensor)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to output/250422_200313/train/250422_200802_FLDetn_plane_Iter_1
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      12.3G       3.29      3.201       3.61         28        640: 100%|██████████| 82/82 [00:20<00:00,  4.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  3.90it/s]
#                    all        218        278    0.00846     0.0216    0.00197    0.00046
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      12.3G      2.699      2.881      3.062         25        640: 100%|██████████| 82/82 [00:19<00:00,  4.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:01<00:00,  4.02it/s]
#                    all        218        278     0.0027      0.518    0.00199   0.000524
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-37fb6e0aa0b9> in <cell line: 0>()
#      32         ex_time = datetime.now().strftime('%y%m%d_%H%M%S')
#      33         output_json_path = f"{ex_time}_{submission_function}_Iter_{iteration}_detection_results.json"
# ---> 34         globals()[submission_function](yaml_path, output_json_path)
#      35         labels_dir = f"Datasets/{Dataset_Name}/labels"
#      36
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/submission_2_20223292.py in submission_2_20223292(yaml_path, output_json_path, config)
#      73     ex_dict['Model'] = model
#      74
# ---> 75     ex_dict = FLDetn.train_model(ex_dict, config)
#      76
#      77     test_images = get_test_images(data_config)
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/FLDetn/FLDetn.py in train_model(ex_dict, config)
#      17     task = "detect"
#      18
# ---> 19     ex_dict['Train Results'] = ex_dict['Model'].train(
#      20         model = f"{ex_dict['Model Name']}.yaml",
#      21         name=name,
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/FLDetn/pkgs/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     345             self.model = self.trainer.model
#     346         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 347         self.trainer.train()
#     348         # Update model and cfg after training
#     349         if RANK in (-1, 0):
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/FLDetn/pkgs/ultralytics/engine/trainer.py in train(self)
#     194
#     195         else:
# --> 196             self._do_train(world_size)
#     197
#     198     def _setup_ddp(self, world_size):
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/FLDetn/pkgs/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     416                 # Save model
#     417                 if self.args.save or (epoch + 1 == self.epochs):
# --> 418                     self.save_model()
#     419                     self.run_callbacks('on_model_save')
#     420
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/FLDetn/pkgs/ultralytics/engine/trainer.py in save_model(self)
#     464
#     465         # Save last and best
# --> 466         torch.save(ckpt, self.last)
#     467         if self.best_fitness == self.fitness:
#     468             torch.save(ckpt, self.best)
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/HyperYOLOt/pkgs/hyper_ultralytics/utils/patches.py in torch_save(*args, **kwargs)
#      75     if 'pickle_module' not in kwargs:
#      76         kwargs['pickle_module'] = pickle  # noqa
# ---> 77     return _torch_save(*args, **kwargs)
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/FLDetn/pkgs/ultralytics/utils/patches.py in torch_save(*args, **kwargs)
#      73     if 'pickle_module' not in kwargs:
#      74         kwargs['pickle_module'] = pickle  # noqa
# ---> 75     return _torch_save(*args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/patches.py in torch_save(*args, **kwargs)
#     103         except RuntimeError as e:  # unable to save, possibly waiting for device to flush or antivirus scan
#     104             if i == 3:
# --> 105                 raise e
#     106             time.sleep((2**i) / 2)  # exponential standoff: 0.5s, 1.0s, 2.0s
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/patches.py in torch_save(*args, **kwargs)
#     100     for i in range(4):  # 3 retries
#     101         try:
# --> 102             return _torch_save(*args, **kwargs)
#     103         except RuntimeError as e:  # unable to save, possibly waiting for device to flush or antivirus scan
#     104             if i == 3:
#
# /content/drive/MyDrive/Colab Notebooks/컴퓨터 비전/CV_midterm_competition_code_v2/models/HyperYOLOt/pkgs/hyper_ultralytics/utils/patches.py in torch_save(*args, **kwargs)
#      75     if 'pickle_module' not in kwargs:
#      76         kwargs['pickle_module'] = pickle  # noqa
# ---> 77     return _torch_save(*args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     941
#     942     if _use_new_zipfile_serialization:
# --> 943         with _open_zipfile_writer(f) as opened_zipfile:
#     944             _save(
#     945                 obj,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _open_zipfile_writer(name_or_buffer)
#     808     else:
#     809         container = _open_zipfile_writer_buffer
# --> 810     return container(name_or_buffer)
#     811
#     812
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in __init__(self, name)
#     779             )
#     780         else:
# --> 781             super().__init__(torch._C.PyTorchFileWriter(self.name, _compute_crc32))
#     782
#     783     def __exit__(self, *args) -> None:
#
# RuntimeError: Parent directory output/250422_200313/train/250422_200802_FLDetn_plane_Iter_1/weights does not exist.

# %%
# 분석 방향에 따라 전체 결과를 모아 평균-표준편차-통계테스트 결과 저장
keep_columns = ['Iteration','Submission Function']
keep_measures = ['IoU','Dice','Precision','Recall']

reduction = 'Iteration'
row = 'Measure Type'
column = 'Submission Function'
reference_column = 'submission_YOLOv8n'

custom_fmt_template = '{mean_fmt} ± {std_fmt} {significance}'
significance_levels = [0.1, 0.05, 0.01]
decimal_places = 3
transpose = True
make_tables(csv_filename, keep_columns, keep_measures, reduction, row, column,
            reference_column, custom_fmt_template, significance_levels, decimal_places, transpose)
